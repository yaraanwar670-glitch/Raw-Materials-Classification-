# %%
# !pip install split-folders
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import splitfolders

input_folder = r"C:\Users\user\OneDrive - Helwan National University\Desktop\project AI2\data set ai"
output_folder = "dataset_split"

splitfolders.ratio(
    input_folder,
    output=output_folder,
    seed=42,
    ratio=(0.7, 0.15, 0.15)
)
# Out:
# Copying files: 10000 files [00:20, 493.54 files/s]
