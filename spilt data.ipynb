# %%
# !pip install split-folders

# %%
import splitfolders

input_folder = r"imagesss"
output_folder = r"dataset_split"

splitfolders.ratio(
    input_folder,
    output=output_folder,
    seed=42,
    ratio=(0.7, 0.10,0.20)
)
